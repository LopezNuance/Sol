# %% [markdown]
# # Checkpoint comparison
# Initial analysis (imported from Jupyter).

# %%
load_checkpoints()
# Out:
# loaded 3 checkpoints

# %%
results['m2000']
# Out:
# Traceback (most recent call last)
# KeyError: 'm2000'
